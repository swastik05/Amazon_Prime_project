# %% [markdown]
# <a href="https://colab.research.google.com/github/swastik05/Amazon_Prime_project/blob/main/Amazon_Prime_TV_Shows_and_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  Amazon Prime TV Shows and Movies Analysis
#
# ![7564181_amazon_prime_logo_brand_icon.png](data:image/png;base64,...)

# %% [markdown]
# ##### **Project Type**- Exploratory Data Analysis (EDA)
# ##### **Contribution**    - Individual
# **Name:-** Swastik Das

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The streaming industry has become one of the fastest-growing segments of the digital economy, with platforms like Amazon Prime Video competing aggressively for audience attention. This project aims to analyze the catalog of Amazon Prime Movies and TV Shows to extract actionable insights regarding audience preferences, content performance, and potential growth opportunities. The analysis particularly focuses on how different variables—such as type of content, IMDB score, release year, and number of seasons—affect user engagement and satisfaction.
#
# The project began with thorough data preparation. The dataset, which contained attributes like title, type, release year, seasons, and IMDB rating, was cleaned by addressing missing values, removing duplicates, and standardizing text fields. This ensured that the dataset was suitable for accurate analysis. Once preprocessing was complete, exploratory data analysis (EDA) techniques were applied using both statistical methods and visualization tools. Graphical methods included bar plots, line charts, and violin plots, each of which revealed distinct insights about the catalog’s structure and performance trends.
#
# One of the most critical findings emerged from the violin plot analysis of IMDB scores by type. The plot revealed that TV Shows tend to achieve more consistent and higher ratings compared to Movies, which show a wider spread of scores ranging from poor to excellent. This indicates that Prime’s TV Shows are perceived as more reliable in quality, whereas Movies carry higher risk in terms of reception. Additionally, trend analysis demonstrated a surge in the release of original TV Shows in recent years, highlighting Amazon’s focus on long-term engagement strategies through serialized content.
#
# Overall, this project underscores the importance of data-driven decision-making in the entertainment sector. By analyzing viewer-oriented metrics like IMDB scores and catalog diversity, Amazon Prime can better align its content strategy with customer expectations. These insights can support sustainable growth, improve customer satisfaction, and provide Amazon with a competitive edge in the crowded OTT streaming market.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The rapid rise of Over-The-Top (OTT) platforms has led to an overwhelming variety of content available to global audiences. Amazon Prime Video, being one of the leading streaming services, hosts thousands of Movies and TV Shows catering to diverse preferences. However, with such vast content, it becomes challenging to identify which types of content drive higher audience satisfaction, retention, and long-term business growth.
#
# Key questions remain unanswered:
#
#
# *   Do TV Shows and Movies perform differently in terms of audience ratings (IMDB scores)?
#
#
#
# *   How has the release trend of content evolved over the years?
#
# *   Which categories of content consistently deliver high quality, and which risk harming customer satisfaction?
#
#
# *   Can content performance insights help Amazon Prime allocate resources more effectively and strengthen its competitive advantage?
#
# Therefore, it is essential to explore the dataset of Amazon Prime Movies and TV Shows to uncover patterns, measure content quality, and generate insights that can support better decision-making for content strategy and business impact.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to perform an in-depth exploratory data analysis (EDA) on the Amazon Prime Video content library to:
#
# 1. **Analyze elements contributing to content performance:** Determine which factors (e.g., content type, genre, age certification, IMDB score) are associated with higher audience engagement and satisfaction.
# 2. **Support strategic content sourcing and creation:** Provide data-backed recommendations for acquiring or producing content that aligns with audience preferences and market trends.
# 3. **Streamline content portfolio management:** Gain insights into the composition of the content library to identify strengths, weaknesses, and opportunities for diversification.
# 4. **Enhance viewer satisfaction and retention:** Ultimately, use the insights gained to improve the overall content offering and keep subscribers engaged with the platform.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # .pyplot Submodule inside the module matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#load 'titles' dataset from the csv file.
titles=pd.read_csv('/content/drive/MyDrive/EDA/titles.csv')

#load 'credits' dataset from the csv file.
credits=pd.read_csv('/content/drive/MyDrive/EDA/credits.csv')

# %%
#check which columns are present in 'title' dataset
titles.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
#check which columns are present in 'credits' dataset
credits.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# After checking columns,we perform merging with inner join for both the datasets on common column
prime = pd.merge(titles, credits, on='id',how="inner")

# %%
prime
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look of first 5 rows after merging both the sets
prime.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3               NaN       78
# 4               NaN       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of rows:", prime.shape[0])
print("Number of columns:", prime.shape[1])
# Out:
# Number of rows: 124347
# Number of columns: 19

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
prime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124347 non-null  object
#  1   title                 124347 non-null  object
#  2   type                  124347 non-null  object
#  3   description           124256 non-null  object
#  4   release_year          124347 non-null  int64
#  5   age_certification     56707 non-null   object
#  6   runtime               124347 non-null  int64
#  7   genres                124347 non-null  object
#  8   production_countries  124347 non-null  object
#  9   seasons               8153 non-null    float64
#  10  imdb_id               119044 non-null  object
#  11  imdb_score            118296 non-null  float64
#  12  imdb_votes            118272 non-null  float64
#  13  tmdb_popularity       124332 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value
duplicate_rows =prime.duplicated().sum()
print("Number of duplicate rows:", duplicate_rows)
# Out:
# Number of duplicate rows: 168

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
prime.isnull().sum()
# Out:
# id                           0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# person_id                    0
# name                         0
# character                16307
# role                         0
# dtype: int64

# %%
# Visualizing the missing values

missing_values = prime.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 6))
missing_values.plot(kind='bar')
plt.title('Missing Values per Column', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Number of Missing Values', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Amazon Prime TV Shows and Movies dataset is a  collection of information about the content available on Amazon Prime Video, one of the largest OTT streaming platforms. It typically includes details about each movie and TV show in the catalog, allowing analysis of content trends, performance, and audience reception. There are a total of 124,347 rows and 19 columns in the merged dataset.It typically includes attributes such as the title of the content, type (Movie or TV Show), release year, number of seasons, genre, description, and IMDB rating.
# In  essence, the dataset acts as a foundation for exploring how Amazon Prime balances its library, the quality of its offerings, and the impact these factors may have on customer satisfaction and business growth.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
list(prime.columns)
# Out:
# ['id',
#  'title',
#  'type',
#  'description',
#  'release_year',
#  'age_certification',
#  'runtime',
#  'genres',
#  'production_countries',
#  'seasons',
#  'imdb_id',
#  'imdb_score',
#  'imdb_votes',
#  'tmdb_popularity',
#  'tmdb_score',
#  'person_id',
#  'name',
#  'character',
#  'role']

# %%
# Dataset Describe
prime.describe(include='all')
# Out:
#               id             title    type  \
# count     124347            124347  124347
# unique      8861              8748       2
# top     tm458582  Coming 2 America   MOVIE
# freq         137               137  116194
# mean         NaN               NaN     NaN
# std          NaN               NaN     NaN
# min          NaN               NaN     NaN
# 25%          NaN               NaN     NaN
# 50%          NaN               NaN     NaN
# 75%          NaN               NaN     NaN
# max          NaN               NaN     NaN
#
#                                               description   release_year  \
# count                                              124256  124347.000000
# unique                                               8833            NaN
# top     Prince Akeem Joffer is set to become King of Z...            NaN
# freq                                                  137            NaN
# mean                                                  NaN    1996.233234
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   id: The title ID on JustWatch.
#
# *   title: The name of the title.
#
# *   show_type: TV show or movie.
#
# *   description: A brief description.
#
# *   release_year: The release year.
#
# *   age_certification: The age certification.
#
# *   runtime: The length of the episode (SHOW) or movie.
#
# *   genres: A list of genres.
#
# *   production_countries: A list of countries that produced the title.
#
# *   seasons: Number of seasons if it's a SHOW.
#
# *   imdb_id: The title ID on IMDB.
#
# *   imdb_score: Score on IMDB.
#
# *   imdb_votes: Votes on IMDB.
#
# *   tmdb_popularity: Popularity on TMDB.
#
# *   tmdb_score: Score on TMDB.
#
# *   person_id: total person id
#
# *   name: name of actors.
#
# *   character: actor playing which character in tv shows/movies
#
# *  role: which role is being played

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in list(prime.columns):
  print("no. of unique values in ",i,"is",prime[i].nunique(),".")
# Out:
# no. of unique values in  id is 8861 .
# no. of unique values in  title is 8748 .
# no. of unique values in  type is 2 .
# no. of unique values in  description is 8833 .
# no. of unique values in  release_year is 110 .
# no. of unique values in  age_certification is 11 .
# no. of unique values in  runtime is 204 .
# no. of unique values in  genres is 1965 .
# no. of unique values in  production_countries is 482 .
# no. of unique values in  seasons is 30 .
# no. of unique values in  imdb_id is 8267 .
# no. of unique values in  imdb_score is 85 .
# no. of unique values in  imdb_votes is 3623 .
# no. of unique values in  tmdb_popularity is 5267 .
# no. of unique values in  tmdb_score is 88 .
# no. of unique values in  person_id is 80508 .
# no. of unique values in  name is 79758 .
# no. of unique values in  character is 71097 .
# no. of unique values in  role is 2 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
prime.dropna(subset=["description"],inplace=True)

# %%
prime
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %%
#check random id whether dataframe is empty or not
id_value = "tm582037"

result = prime.loc[prime["id"] == id_value, ["id", "description"]]
print(result)
# Out:
# Empty DataFrame
# Columns: [id, description]
# Index: []

# %%
prime.shape
# Out:
# (124256, 19)

# %%
#counts the total number of each category of age certification
print(prime["age_certification"].value_counts())
# Out:
# age_certification
# R        25926
# PG-13    12475
# PG        9608
# G         3839
# TV-MA     1732
# TV-14     1583
# TV-PG      501
# TV-Y7      356
# TV-Y       298
# TV-G       242
# NC-17      116
# Name: count, dtype: int64

# %%
prime["age_certification"].mode()[0] #check frequently occuring age certification
# Out:
# 'R'

# %%
count_R = (prime["age_certification"] == "R").sum()
print("R is repeated", count_R, "times")
# Out:
# R is repeated 25926 times

# %%
prime["age_certification"].fillna(prime["age_certification"].mode()[0], inplace=True) #replace empty age certification with R

# %%
#check whether empty age certification is filled up
for value in prime["age_certification"].head(20):
    print(value)
# Out:
# TV-PG
# TV-PG
# TV-PG
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R
# R

# %%
#replace empty age certification with R
prime["seasons"] = prime["seasons"].fillna(0)

# %%
for value in prime["seasons"].head(): #check empty cell of seasons is filled with 0.0 or not.
    print(value)
# Out:
# 26.0
# 26.0
# 26.0
# 0.0
# 0.0

# %%
prime
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %%
prime[prime["id"].between('tm5168', 'tm137298')]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
#'imdb_id' is unique for Movies and TV shows, we will drop all null entries in 'imdb_id' columns.
prime.dropna(subset=['imdb_id'], inplace=True)

# %%
round(prime['imdb_score'].mean(),1) #round imdb_score to one decimal place
# Out:
# np.float64(6.0)

# %%
prime.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3                 R       78
# 4                 R       78
#
#                                               genres production_countries  \
# ...

# %%
prime['imdb_score'].fillna(round(prime['imdb_score'].mean(),1), inplace=True)

# %%
# Suppose the column is "id" and you want id = "tm5168"
id_value = "tm74259"

row = prime[prime["id"] == id_value]
print(row)
# Out:
#           id                     title   type  \
# 792  tm74259  The Pride of the Yankees  MOVIE
# 793  tm74259  The Pride of the Yankees  MOVIE
# 794  tm74259  The Pride of the Yankees  MOVIE
# 795  tm74259  The Pride of the Yankees  MOVIE
# 796  tm74259  The Pride of the Yankees  MOVIE
# 797  tm74259  The Pride of the Yankees  MOVIE
# 798  tm74259  The Pride of the Yankees  MOVIE
# 799  tm74259  The Pride of the Yankees  MOVIE
# 800  tm74259  The Pride of the Yankees  MOVIE
# 801  tm74259  The Pride of the Yankees  MOVIE
# 802  tm74259  The Pride of the Yankees  MOVIE
# 803  tm74259  The Pride of the Yankees  MOVIE
# 804  tm74259  The Pride of the Yankees  MOVIE
# 805  tm74259  The Pride of the Yankees  MOVIE
# 806  tm74259  The Pride of the Yankees  MOVIE
# 807  tm74259  The Pride of the Yankees  MOVIE
# 808  tm74259  The Pride of the Yankees  MOVIE
# 809  tm74259  The Pride of the Yankees  MOVIE
# 810  tm74259  The Pride of the Yankees  MOVIE
# ...

# %%
#now we can see the columns which have null values
prime.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                  0
# imdb_votes                770
# tmdb_popularity            13
# tmdb_score               9118
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %%
# Missing values in 'imdb_votes' may indicate movie is relatively new or has not gained much attention. It's better to replace the null values with 0.
prime['imdb_votes'].fillna(0, inplace=True)

# %%
prime['tmdb_popularity'].fillna(round(prime['tmdb_popularity'].mean(),2), inplace=True) #round tmdb_popularity to average

# %%
prime.head(10)
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
# 5  tm19248        The General  MOVIE
# 6  tm19248        The General  MOVIE
# 7  tm19248        The General  MOVIE
# 8  tm19248        The General  MOVIE
# 9  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
# 5  During America’s Civil War, Union spies steal ...          1926
# 6  During America’s Civil War, Union spies steal ...          1926
# ...

# %%
# Suppose the column is "id" and you want id = "tm5168"
id_value = "ts187948"

row = prime[prime["id"] == id_value]
print(row)
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
#now we can see the columns which have null values
prime.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                  0
# imdb_votes                  0
# tmdb_popularity             0
# tmdb_score               9118
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %%
#Fills all the NaN (missing) values in the column with that rounded mean value.
prime['tmdb_score'].fillna(round(prime['tmdb_score'].mean(),1),inplace=True)

# %%
#replaces all NaN (missing/null values) in that column with the string 'unknown'.
prime['character'].fillna('unknown',inplace=True)

# %%
#now we can see we have cleaned and conducted operations on various columns as and when needed.
prime.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %%
prime.shape
# Out:
# (119022, 19)

# %%
#Check for Duplicate values
prime.duplicated().sum()
# Out:
# np.int64(168)

# %%
prime.drop_duplicates(inplace=True)

# %%
prime.duplicated().sum()
# Out:
# np.int64(0)

# %%
prime.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# person_id                 int64
# name                     object
# character                object
# role                     object
# dtype: object

# %%
prime.describe()
# Out:
#         release_year        runtime        seasons     imdb_score  \
# count  118854.000000  118854.000000  118854.000000  118854.000000
# mean     1995.694592      96.054453       0.153466       5.968800
# std        28.010517      29.798646       1.006917       1.238147
# min      1912.000000       1.000000       0.000000       1.100000
# 25%      1980.000000      83.000000       0.000000       5.200000
# 50%      2009.000000      94.000000       0.000000       6.000000
# 75%      2017.000000     109.000000       0.000000       6.800000
# max      2022.000000     328.000000      49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score     person_id
# count  1.188540e+05    118854.000000  118854.000000  1.188540e+05
# mean   2.312887e+04        10.334860       5.997704  3.976869e+05
# std    8.819975e+04        40.786345       1.252196  5.549632e+05
# min    0.000000e+00         0.000164       0.800000  1.000000e+00
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# 1.   List item
# 2.   List item

# %% [markdown]
# Answer Here.

# %% [markdown]
# ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Box plot of IMDB Score
plt.figure(figsize=(8,5));
sns.boxplot(x='imdb_score',data=prime)
plt.title("Box plot of IMDB Score",color='red',fontsize=16)
plt.xlabel('IMDB Score',color='black',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen because it quickly shows data distribution,spread,outliers,etc in IMDB scores. Unlike a histogram, it gives a concise statistical summary without clutter, making it easier to spot unusual values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most movies and tv showsfall within a certain score range (interquartile range).
#       ->Most TV Shows and movies in the dataset have average ratings between 5.5 and 7.
#
#
#       ->A few TV Shows and movies are very low-rated (outliers < 2).
#
#
#        ->Very few TV Shows and movies are highly rated (score > 9.5).
#
# *   The median IMDB score shows the typical rating audience gives.
#
#
# *   Presence of outliers reveals some movies are rated exceptionally low or high.
# *   The spread indicates whether ratings are consistent or widely varying.

# %% [markdown]
# ####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#
#
#   **✅Positive Impact:**
#
#
#
#
# *   If most movies an tv shows cluster around average scores, business teams can identify the traits of higher-rated movies and replicate them.
#
# *   Outliers with very high ratings highlight success formulas (genre, cast, production quality) worth investing in.
#
# *   Poorly rated outliers help avoid repeated mistakes in future productions.
#
#
# *   Maintaining consistent quality improves customer trust and retention, directly impacting subscription or box-office revenue.
#
#
#
#
#
#
#
#
#
#
#
#   🚫 **Potential Negative Growth Insight**:
#
#
# *   If the median score is low (say <4), it indicates overall quality dissatisfaction, which can harm brand perception and reduce customer engagement.
#
#
# *   Wide variability means inconsistent quality, which may confuse the audience and affect retention.
#
#
# *   Too many outliers on the lower end highlight inefficient resource allocation that should be corrected to avoid financial losses.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Box plot of Runtime
plt.figure(figsize=(8,5))
sns.boxplot(x='runtime',data=prime)
plt.title("Box plot of Runtime",color='red',fontsize=14)
plt.xlabel('Runtime',color='black',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was selected because it gives a concise statistical view of runtimes without overwhelming detail. It effectively shows the central tendency (median), the distribution of most titles (interquartile range), and extreme cases (outliers) that may represent very short or very long content. Compared to other charts, it is more efficient in detecting runtime consistency, anomalies, and patterns at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The median runtime indicates the standard length most movies fall into.
#     Most movies/tv shows is between 85 to 125 minutes long
# *   The interquartile range (IQR) shows how varied runtimes are across the      dataset.
#
# *   Presence of outliers reveals movies that are significantly shorter (possibly shorts or episodes) or much longer (may be documentaries, series episodes, etc.)).
# *   If the box is narrow, it suggests runtime consistency; if wide, movies vary widely in duration.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#
# *   Understanding the standard runtime helps align content with audience attention spans, improving viewer satisfaction and retention.
#
# *   Insights on longer movies may guide premium positioning (e.g., epic films for theaters or special releases).
#
# *   Shorter runtime clusters may indicate opportunities for snackable content,
# catering to casual or mobile viewers.
#
# 🚫 Negative growth risk:
#
#
#
# *   Too much variability in runtime could confuse audience expectations, reducing engagement.
#
# *   Extremely long runtimes may discourage viewers, leading to drop-offs and lower watch completion rates.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Histogram of release year
plt.figure(figsize=(9,5))
sns.histplot(x='release_year',data=prime,bins=25,color='darkblue',edgecolor='black',kde=True)
plt.title('Histogram of Release Years', color='red', fontsize=14)
plt.xlabel('Release Year', color='black',fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because it effectively shows the distribution of content over time. It helps identify patterns such as production peaks, growth trends, or periods with fewer releases, which line charts or box plots may not capture as clearly for discrete year data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most content is clustered in recent years, indicating a surge in production.
#
# *   Earlier decades show fewer releases, which may be due to either historical production limits or incomplete data.
#
# *   The KDE curve highlights the overall trend, making it easier to see whether production is growing steadily or fluctuating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#  Yes. The insights can guide strategic content planning by showing which time periods produce the most marketable titles.
# ✅ Increasing recent releases suggests stronger engagement opportunities for audiences interested in newer content.
#
# ⚠️ Potential negative implications:
#
# Concentration of content in recent years may reduce catalog diversity, which could limit engagement for audiences seeking classic or older titles.
#
# Uneven production across years could indicate risks in relying on trends without consistent long-term planning.
# ⚠️ However, a concentration only in recent years may limit catalog diversity, potentially reducing appeal for users seeking classic or older titles.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Histogram of Runtime
plt.figure(figsize=(8,4))
sns.histplot(x='runtime',data=prime,bins=25,color='darkblue',edgecolor='black',kde=True)
plt.title('Histogram of Runtime', color='red', fontsize=14)
plt.xlabel('Runtime', color='black',fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because it clearly shows the distribution of runtimes across all movies/TV shows for indivisual continuous variable. It highlights  runtime ranges, runtimes are normally distributed or skewed, and makes it easy to spot unusual gaps or peaks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most movies/tv shows fall within a specific runtime range (e.g., 90–120 minutes),
# highlights an industry standard.
#
# *  The KDE curve shows the overall shape of runtime distribution — whether it’s centered around one range or spread out.
#
# *  Some movies/shows fall into the very short or very long categories, which may represent short films, documentaries, or epic-length content.
#
# *   Peaks may indicate popular content lengths favored by audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#
# *   Identifying the accurate runtime range helps producers create content that aligns with audience attention spans, improving satisfaction and engagement.
#
# *   Shorter runtime clusters can reveal opportunities for content, while standard runtimes ensure broad appeal.
#
# *   Longer runtimes may be positioned as premium or special event releases.
#
# 🚫 Negative growth risk:
#
# *  Overproduction of unusually long titles may lead to viewer distress and lower completion rates.
#
# *  Too much variability in runtimes can create inconsistent audience experiences, reducing loyalty.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Histogram of Season
plt.figure(figsize=(8,4))
sns.histplot(x='seasons',data=prime,bins=25,color='green',edgecolor='black')
plt.title('Histogram of Seasons', color='red', fontsize=14)
plt.xlabel('Seasons',color='black',fontsize=12)
plt.ylabel('Count',color='black',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because it provides a clear picture of how TV shows are distributed by the number of seasons(numerical data). Thus, the histogram is the most suitable chart when the goal is to understand how often values fall within specific ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Most shows are of 1 or 2 seasons, suggesting a majority of titles are short-run.
#
# *  Few shows extend beyond 5+ seasons, indicating that long-running series are rare.
# *  Peaks represent the most common season counts preferred by both creators and audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
# * Helps the content producers align with audience preferences for shorter, high-impact shows.
#
# * Identifies opportunities to invest in long-running shows, which can build loyal audiences and stable revenue systems.
# * The histogram shows peak at one as number of seasons only applicable to TV shows, Movies don't have seasons.
#
# 🚫 Negative growth risk:
# *  Over-reliance on short-run shows may reduce long-term audience engagement.
# * Limited long-running series could weaken brand identity and competitiveness against platforms known for strong franchises.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#Histogram of imdb_score
plt.figure(figsize=(8,4))
sns.histplot(x='imdb_score',data=prime,bins=20,color='green',edgecolor='black',kde=True)
plt.title('Histogram of IMDB Score',color='red',fontsize=14)
plt.xlabel('IMDB SCORE',color='black',fontsize=12)
plt.ylabel('Count',color='black',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is ideal because it clearly shows the distribution of IMDB scores(numerical data) across all titles. It helps identify whether ratings are
# concentrated in certain ranges (e.g., mostly average, mostly high,spread out).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Peaks in certain ranges reveal the most common IMDB scores given to titles.
#
# *  The spread shows whether most content performs consistently or varies widely in audience ratings.
#
# * Outliers (very high or very low scores) indicate exceptionally well-received or poorly received titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#
# *  Helps platforms focus on producing content within high-rating ranges to maintain audience trust and satisfaction.
# *  This leads to high customer engagement and help in growth of revenue.
#
# *   higher imdb scores boost brand reputation in the market
#
# 🚫 Negative growth risk:
# *   Too many low-scoring titles may hurt brand credibility and reduce user retention.
# *   Identifies poorly rated content that could harm retention and suggests areas for quality enhancement.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
##count plot of type(Movie or TV show)
plt.figure(figsize=(8,4))
ax=sns.countplot(x='type',data=prime,palette='crest',edgecolor='black')
for container in ax.containers:
  ax.bar_label(container,color='purple',fontsize=10)
plt.title('Count plot of type(Movie or TV show)',color='red',fontsize=15)
plt.xlabel('Type',color='black',fontsize=12)
plt.ylabel('Count',color='black',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen because it clearly shows the distribution of categorical data, in this case, Movies vs TV Shows. It quickly highlights which type dominates the platform and is more intuitive than tables or pie charts for comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *    Movies have a higher count than the other, showing platform focus of the audeince.
# *   Another insight, the content of the movies may be good compared to show
# *   There are 1,11,454 Movies compared to 7,400 Shows only.
# *  We can find from the above chart that Movies to show ratio is 15 : 1.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# ✅ Positive impact:
#
#
#
# *   Helps content strategy planning by showing which type (Movie or TV Show) dominates and where to invest resources.
#
#
# *   Enables marketing campaigns to highlight popular content types to attract and retain users.
#
#
# *   Assists in recommendation sytem optimization by understanding the content mix and improving personalization.
#
#
#
#
#
# Helps content strategy planning by showing which type (Movie or TV Show) dominates and where to invest resources.
#
#
# 🚫 Negative growth risk:
# *  Overproduction of one type may lead to content imbalance, reducing appeal to broader audiences.
#
#
# *   Ignoring underrepresented content types could limit audience growth in certain segments.
#
# *   Heavy focus on one type might make the platform less competitive compared to platforms with a more diverse offering.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#count plot of age certification
plt.figure(figsize=(8,4))
pd = sns.countplot(x='age_certification', data=prime, palette= 'icefire', edgecolor='black')
for container in pd.containers:
 pd.bar_label(container, color='purple', fontsize=10)
plt.title('Count of Age Certification', fontsize=14, color='red')
plt.xlabel('Age Certification', fontsize=12, color='black')
plt.ylabel('Count', fontsize=12, color='black')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot is the best choice here because it visually compares categorical data (age certification). Unlike a pie chart or table, it allows for easy side-by-side comparison of counts across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Here we can see in above chart that R- restricted content dominates the age certification criteria with 88755 titles.
# *   PG-13: 12,302 titles – for age 13 and below under parental guidance.
#  PG: 9,437 titles – for general audiences with parental guidance.
#  G: 3,674 titles – for general audiences, suitable for all ages.
#
#
# *   We can find here children specific content is less:
# TV-Y (293), TV-Y7 (353), TV-G (240), and TV-PG (494) have very low counts, indicating less focus on
# children's programming in this dataset.
#
# *   Only 116 titles are rated NC-17, showing that content with very strict age restrictions is rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#
#
#
# *   Helps in audience targeting platform can design campaigns around the most common age groups.
#
#
# *   Ensures regulatory compliance by monitoring the mix of certifications.
#
# *   Identifies growth opportunities in underserved categories (e.g., children’s content).
#
# 🚫 Negative growth risk:
# * Heavy traffic toward a single age group may limit audience reach.
# * Too few titles in family or mature categories may result in missed revenue opportunities from those segments.
#
#
#
# *   Lack of balance in certifications could lead to viewer dissatisfaction if certain age groups feel underserved.

# %% [markdown]
# #### Chart - 9

# %%
print(sns.palettes.SEABORN_PALETTES.keys())
# Out:
# dict_keys(['deep', 'deep6', 'muted', 'muted6', 'pastel', 'pastel6', 'bright', 'bright6', 'dark', 'dark6', 'colorblind', 'colorblind6'])

# %%
# Step 1: Count value of genres
genre_counts = prime['genres'].value_counts()
# Step 2: Filter genres with count > 1000
prime_genres = genre_counts[genre_counts > 1000].index
#This line filters the original DataFrame psd to keep only those rows where the value in the psd_Data = psd[psd['genres'].isin(psd_genres)]
prime_Data = prime[prime['genres'].isin(prime_genres)]
plt.figure(figsize=(12, 6))
dp = sns.countplot(y='genres', data=prime_Data, palette='rocket_r', edgecolor='black')
for container in dp.containers:
 dp.bar_label(container, color='purple', fontsize=10)
plt.title('Count plot for Genres', color='red', fontsize=20)
plt.xlabel('Count', color='blue', fontsize=14)
plt.ylabel('Genres', color='blue', fontsize=14)
plt.tight_layout() # It is use for Automatically adjusts the subplot parameters so that:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots are the best choice for categorical variables like genres. Filtering by >1000 ensures focus on significant genres instead of cluttering with rare categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Shows which genres dominate the content library.
# *   Highlights whether the platform caters more to mainstream or niche audiences.
#
# *   Helps detect low represented genres that could be growth opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
#
# *   helps investing in advertisement and target audience which genres attract viewership.
# *   helps in guiding popular genres to invest more.
# *   has postive impact on subscriber retention and growth coinciding with user preferences.
#
#
#
#
#
# 🚫 Negative growth risk:
#
# *   Genres should be diversified if it lack variety may fall behind to competitors.
# *   more focus on niche genras may miss oppertunity on emerging content.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#### Count plot of production countries
# Step 1: Count value of production countries
count_production_countries=prime['production_countries'].value_counts()
# Step 2: Filter genres with count >500
prime_production_countries=count_production_countries[count_production_countries>500].index
#This is orginal DataFrame psd to keep only those rows where the value in the 'production_psd_p_Data=psd[psd['production_countries'].isin(psd_production_countries)]
prime_Data=prime[prime['production_countries'].isin(prime_production_countries)]
plt.figure(figsize=(12, 6))
xp=sns.countplot(y='production_countries',data=prime_Data,palette='coolwarm', edgecolor='black')
for container in xp.containers:
 xp.bar_label(container, color='purple')
plt.title('Count plot of Production Countries', color='red',fontsize=20)
plt.xlabel('Count',color='blue',fontsize=14)
plt.ylabel('Production Countries',color='blue',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is the most effective way to compare categorical data like countries. Filtering for >500 titles ensures focus on the key contributors rather than focus on less frequent countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset is dominated by US-produced content, followed by India and the UK. Other countries like
# Japan, France, Canada, and Australia also contribute significantly. The presence of multiple co-productions
# reflects the global nature of the entertainment industry. However, there's a clean lean toward
# English-speaking countries, particularly the USA

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive:
#
#
#
# *   Helps in having good relationship with production hubs to expand popular content.
#
# *   Supports regional marketing strategies by knowing which countries dominate the title.
#
# *   helps in content localization and dubbing priorities based on top producers.
#
# 🚫 Negative growth risk:
#
#
# *   Overdependence on a few countries may reduce cultural improtance and limit global reach.
#
# *   missed/less representation of certain regions may lead to missed opportunities in expanding to new markets.

# %% [markdown]
# #### Chart - 11

# %%
#Chart - 11 visualization code
#Count plot of average rating for each age certification
#Step 1: Group by age certification and calculate average rating
avg_rating_df = prime.groupby('age_certification')['imdb_score'].mean().reset_index()
#Step 2: Sort (optional, for better visualization)
avg_rating_df = avg_rating_df.sort_values(by='imdb_score', ascending=False)
#Step 3: Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(x='age_certification', y='imdb_score', data=avg_rating_df, palette='husl')
#Step 4: Add labels on top of each bar
for container in ax.containers:
 ax.bar_label(container, fmt='%.2f', fontsize=10, color='black')
# Step 5: Titles and labels
plt.title('Average Rating by Age Certification', fontsize=16, color='red')
plt.xlabel('Age Certification', fontsize=12, color='blue')
plt.ylabel('IMDB Score', fontsize=12, color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is suitable for comparing a numerical variable (average IMDB score) across different categorical groups (age certification). It clearly shows the average score for each age certification, making it easy to identify which certifications tend to have higher or lower ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The bar plot displays the average IMDB score for each age certification category.
#
#
#
# *   It shows which age certifications have the highest and lowest average ratings.
#
#
# *   You can observe the relative differences in average scores between different age certification groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# * If TV Shows consistently score higher, platforms can invest more in producing/acquiring TV content, knowing it’s more positively received.
#
#
#
# * If Movies have higher variance, platforms can analyze which genres/lengths succeed vs fail and optimize investments accordingly.
#
#
# * High IMDB scores correlate with viewer retention, word-of-mouth marketing, and subscription renewals, so insights can directly guide content strategy.
#
#
#
#
#
#
#
#
# 🚫 Negative Growth Risk:
#
# * If certain age certifications consistently have low average IMDB scores, it might indicate a need to improve the quality of content within those categories.
# * A large proportion of low-scoring content for a specific age group could lead to dissatisfaction and churn among viewers in that demographic.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Scatter plot of imdb_vote and imdb_scores
plt.figure(figsize=(10,5))
sns.scatterplot(x='imdb_votes',y='imdb_score',data=prime,hue='type',palette='mako')
plt.title('Scatter Plot of IMDB Votes vs IMDB Scores by Type',color='red', fontsize=14)
plt.xlabel('IMDB Vote',color='blue',fontsize=14)
plt.ylabel('IMDB Score',color='blue',fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is chosen because it’s the best way to visualize the relationship between two numerical variables (imdb votes vs imdb scores). Adding hue reveals how Movies and TV Shows compare within this relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Shows whether popular titles with high votes are also high-scoring or not.
#
#
#
#
# *   many average-scoring titles with low votes
#
#
# *   Detects outliers: titles with very high scores but surprisingly low votes (hidden insight).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive:
#
#
# *   Enables platforms to discover viewer preferences by analyzing correlation between votes and scores.
#
#
# *   Helps platforms identify highly rated but under-voted titles worth promoting.
#
# *   Helps in  positioning of new releases by marking against existing vote score patterns.
#
#
# *   Provides data for content algorithms balancing quality and popularity.
#
#
# *   It guides marketing spends where audience engagement is high and vice versa.
#
# 🚫 Negative:
#
#
# *   Heavy reliance on votes may bias strategies toward main content, ignoring niche but high-quality titles.
#
# *   Low-scoring but high-vote titles could reduce brand perception if promoted too heavily.
#
# *   Over-prioritizing vote counts may overlook emerging content that hasn’t gained attraction yet.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#line plot of seasons v/s release_year
plt.figure(figsize=(8,4))
sns.lineplot(x='release_year',y='seasons',data=prime)
plt.title('Line plot of Seasons V/S Release Year',color='red',fontsize=14)
plt.xlabel('Release Year',color='blue',fontsize=14)
plt.ylabel('Seasons',color='blue',fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is suitable for visualizing the trend of the number of seasons over time (release year). It helps in identifying if there is any pattern or change in the number of seasons produced for shows over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The line plot shows that the average number of seasons for TV shows has remained relatively low and consistent across the years, with some fluctuations.
# * There are spikes in earlier years, which might represent a few very long-running shows from that period, or it could be an artifact of the data distribution (e.g., fewer shows in earlier years).
# *   Small Dip &
# Rise (Post-2000), some fluctuations seen but overall a growing trend in shows having more than one season.
# Indicates rise of streaming platforms, binge-worthy content, and more serialized formats
#
#
# * Some spikes, especially around mid-1980s and late 1990s.
# This depicts popular or long-running series became more common during this time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive impact:
#
# * Understanding the trend in the number of seasons helps in planning for content production and acquisition, aligning with the prevailing trend of shorter series.
# * It can inform decisions about investing in long-running shows versus limited series.
#
# 🚫 Negative growth risk:
#
# * If the audience prefers longer series and the platform primarily offers short-run shows, it could lead to dissatisfaction and potentially negative growth.
# * A lack of diverse offerings in terms of season length might make the platform less appealing to a wider audience.

# %% [markdown]
# #### Chart - 14

# %%
# Correlation Heatmap visualization code
#line plot of imdb_score v/s release_year
plt.figure(figsize=(7,4))
sns.lineplot(x='release_year',y='imdb_score',data=prime)
plt.title('Line plot of IMDB Score V/S Release Year',color='darkblue',fontsize=14)
plt.xlabel('Release Year',color='darkblue',fontsize=14)
plt.ylabel('IMDB Score',color='darkblue',fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is suitable for visualizing the trend of IMDB scores over time (release year). This helps to see if there is any general change or pattern in how content has been rated over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The line plot shows fluctuations in average IMDB scores across different release years.
# * There isn't a clear upward or downward trend across the entire period, suggesting that average IMDB scores haven't consistently increased or decreased over time.
# * Some years may have higher or lower average scores, indicating periods with potentially better or worse-received content.

# %% [markdown]
# 3. Will the gained insights help creating a positive business
# impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# #### Positive Impact:
#
# * Analyzing periods with higher average IMDB scores can help identify factors (e.g., genres, production styles, historical events) that may contribute to better-received content.
# * This information can guide future content development and acquisition decisions to improve overall content quality and audience satisfaction.
#
# #### Negative Growth Risk:
#
# * If there are periods with consistently low average IMDB scores, it could indicate issues with content quality during those times, potentially leading to viewer dissatisfaction and churn if not addressed.
# * Fluctuations without a clear trend might make it challenging to consistently predict audience reception based solely on the release year.

# %% [markdown]
# **CHART - 15**

# %%
####Pie chart of type(Movie or TV show)
# Count the values once and store it
type_counts = prime['type'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(type_counts, labels=type_counts.index, autopct='%.2f%%',explode =[0.2, 0],shadow=True)
plt.title('Pie chart of Type (Movie or TV Show)', color='red')
plt.legend(type_counts.index, title="Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A pie chart is ideal for showing the proportion of different categories within a circle. In this case, it clearly illustrates the distribution of content types (Movies vs. TV Shows) on the platform.
#
# ##### 2. What is/are the insight(s) found from the chart?
#
# * The pie chart clearly shows that Movies make up a significantly larger proportion of the content on the platform compared to TV Shows.
# * The exact percentages are displayed on the chart, providing a precise understanding of  both the types.
#
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# ✅ Positive Impact:
#
# * The insight into the dominant content type can guide content acquisition strategies, ensuring the platform invests in content that aligns with  and audience preferences.
# * It helps in allocating marketing resources effectively by focusing on the content type that is more prevalent.
#
# 🚫 Negative Growth Risk:
#
# * An overemphasis on one content type might loose users who prefer the other, potentially limiting the platform's appeal to a broader audience.
# * If the market trend shifts towards the less dominant content type, the platform might be slow to adapt, leading to a loss of subscribers to competitors with a more balanced offering.

# %% [markdown]
# **CHART - 16**

# %%
#Violin Plot of imdb_score by type
plt.figure(figsize=(8, 4))
sns.violinplot(x='type', y='imdb_score', data=prime)
plt.title('Violin Plot of IMDB Score by Type',color='red',fontsize=14)
plt.xlabel('Type',color='blue',fontsize=14)
plt.ylabel('IMDB Score', color='blue',fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# It shows the distribution of a numerical variable (IMDB score) across different categories (Movie or TV Show). It provides more detail about the distribution shape than a box plot, including multiple peaks.
#
#
# ##### 2. What is/are the insight(s) found from the chart?
#
# * The violin plot shows the distribution of IMDB scores for both Movies and TV Shows.
# * You can compare the median, interquartile range, and the overall shape of the distribution for each type.
# * It helps to see if one type generally has higher or more consistent scores than the other.
#
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# ✅ Positive Impact:
#
# * Understanding the score distribution for each content type helps in setting quality benchmarks and identifying areas for improvement.
# * If one type consistently has higher scores, it might indicate audience preference and guide content investment.
#
# 🚫 Negative Growth Risk:
#
# * If one content type has a significantly lower and wider spread of scores, it could indicate quality issues that might negatively impact viewer satisfaction and retention for that type.
# * A large number of low-scoring titles in either category can hurt the platform's reputation.

# %% [markdown]
# #### Chart - 17 - Pair Plot

# %%
# Pair Plot visualization code
#Pairplot
sns.pairplot(prime)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is useful for visualizing the relationships between multiple numerical variables in a dataset. It creates a grid of scatter plots for each pair of numerical columns and histograms for individual columns, allowing for a quick overview of correlations, distributions, and potential outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The histograms on the diagonal show the distribution of each numerical variable (runtime, seasons, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, release_year).
# * The scatter plots reveal potential relationships between pairs of variables. For example, you can observe if there's a correlation between imdb_score and imdb_votes, or runtime and tmdb_popularity.
# * Outliers can be easily spotted in the scatter plots as points that lie far from the main cluster of data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# ✅ Positive Impact:
#
# * Identifying correlations between variables can inform content strategy. For instance, if higher runtime correlates with lower scores, it might suggest optimizing content length.
# * Understanding the distribution of variables helps in setting realistic benchmarks for new content (e.g., target imdb_score or runtime).
# * Spotting outliers can lead to investigating exceptional content (both good and bad) to learn from successes and failures.
#
# 🚫 Negative Growth Risk:
#
# * Misinterpreting correlations as causation can lead to flawed content decisions.
# * Focusing too much on statistical relationships might overshadow the importance of creative quality and audience preferences not captured by these numerical variables.

# %% [markdown]
# **CHART - 18 - HEAT MAP**

# %%
##HEATMAP
numeric_col=prime.select_dtypes(include=['int64','float64'])
plt.colormaps()
plt.figure(figsize=(14,6))
sns.heatmap(numeric_col.corr(),annot=True,cmap='crest')
plt.show()

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Write** the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
# Show duplicate rows
duplicate_rows_data = prime[prime.duplicated()]
display(duplicate_rows_data)
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
prime[prime["id"]=='tm89134']
# Out:
#            id                  title   type  \
# 9132  tm89134  The Gunman From Bodie  MOVIE
# 9133  tm89134  The Gunman From Bodie  MOVIE
# 9134  tm89134  The Gunman From Bodie  MOVIE
# 9135  tm89134  The Gunman From Bodie  MOVIE
# 9136  tm89134  The Gunman From Bodie  MOVIE
# 9137  tm89134  The Gunman From Bodie  MOVIE
# 9138  tm89134  The Gunman From Bodie  MOVIE
# 9139  tm89134  The Gunman From Bodie  MOVIE
# 9140  tm89134  The Gunman From Bodie  MOVIE
# 9141  tm89134  The Gunman From Bodie  MOVIE
# 9142  tm89134  The Gunman From Bodie  MOVIE
# 9143  tm89134  The Gunman From Bodie  MOVIE
# 9144  tm89134  The Gunman From Bodie  MOVIE
# 9145  tm89134  The Gunman From Bodie  MOVIE
# 9146  tm89134  The Gunman From Bodie  MOVIE
# 9147  tm89134  The Gunman From Bodie  MOVIE
# 9148  tm89134  The Gunman From Bodie  MOVIE
# 9149  tm89134  The Gunman From Bodie  MOVIE
# 9150  tm89134  The Gunman From Bodie  MOVIE
# 9151  tm89134  The Gunman From Bodie  MOVIE
# ...

# %%
# Missing Values/Null Values Count
print("Missing values per column:")
display(dataset.isnull().sum())
# Out:
# Missing values per column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2611358546.py in <cell line: 0>()
#       1 # Missing Values/Null Values Count
#       2 print("Missing values per column:")
# ----> 3 display(dataset.isnull().sum())
#
# NameError: name 'dataset' is not defined

# %%
# Get the indices of the duplicate rows
duplicate_indices = dataset[dataset.duplicated()].index.tolist()
print(duplicate_indices)
